# %%
pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyspark in /usr/local/lib/python3.7/dist-packages (3.3.0)
# Requirement already satisfied: py4j==0.10.9.5 in /usr/local/lib/python3.7/dist-packages (from pyspark) (0.10.9.5)

# %%
pip install findspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: findspark in /usr/local/lib/python3.7/dist-packages (2.0.1)

# %%
# !pip install unidecode
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: unidecode in /usr/local/lib/python3.7/dist-packages (1.3.4)

# %%
#Importando Bibliotecas e Iniciando o Spark
import findspark
findspark.init()

import pandas as pd
import requests
import json
import unidecode
from pyspark.sql import SparkSession
from pyspark import SparkContext, SparkConf

conf = SparkConf().setAppName("projeto").setMaster("local[1]")
sc = SparkContext(conf = conf)

spark = SparkSession.builder \
      .master("local[1]") \
      .appName("projeto") \
      .getOrCreate()

# %%
# Buscar as cidades do Rio de Janeiro utilizando API do IBGE
URL = "https://servicodados.ibge.gov.br/api/v1/localidades/microrregioes/33001|33002|33003|33004|33005|33006|33007|33008|33009|33010|33011|33012|33013|33014/municipios"
r = requests.get(url = URL) 
data = r.json()

# %%
# Verificar retorno do request
data
# Out:
# [{'id': '3300100',
#   'microrregiao': {'id': 33013,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3305,
#     'nome': 'Sul Fluminense'},
#    'nome': 'Baía da Ilha Grande'},
#   'nome': 'Angra dos Reis',
#   'regiao-imediata': {'id': 330002,
#    'nome': 'Angra dos Reis',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3301,
#     'nome': 'Rio de Janeiro'}}},
#  {'id': '3300159',
#   'microrregiao': {'id': 33002,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3301,
#     'nome': 'Noroeste Fluminense'},
#    'nome': 'Santo Antônio de Pádua'},
#   'nome': 'Aperibé',
#   'regiao-imediata': {'id': 330012,
#    'nome': 'Santo Antônio de Pádua',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3304,
#     'nome': 'Campos dos Goytacazes'}}},
#  {'id': '3300209',
#   'microrregiao': {'id': 33010,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3304,
#     'nome': 'Baixadas'},
#    'nome': 'Lagos'},
#   'nome': 'Araruama',
#   'regiao-imediata': {'id': 330013,
#    'nome': 'Cabo Frio',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3305,
#     'nome': 'Macaé - Rio das Ostras - Cabo Frio'}}},
#  {'id': '3300225',
#   'microrregiao': {'id': 33005,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Centro Fluminense'},
#    'nome': 'Três Rios'},
#   'nome': 'Areal',
#   'regiao-imediata': {'id': 330007,
#    'nome': 'Petrópolis',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Petrópolis'}}},
#  {'id': '3300233',
#   'microrregiao': {'id': 33010,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3304,
#     'nome': 'Baixadas'},
#    'nome': 'Lagos'},
#   'nome': 'Armação dos Búzios',
#   'regiao-imediata': {'id': 330013,
#    'nome': 'Cabo Frio',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3305,
#     'nome': 'Macaé - Rio das Ostras - Cabo Frio'}}},
#  {'id': '3300258',
#   'microrregiao': {'id': 33010,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3304,
#     'nome': 'Baixadas'},
#    'nome': 'Lagos'},
#   'nome': 'Arraial do Cabo',
#   'regiao-imediata': {'id': 330013,
#    'nome': 'Cabo Frio',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3305,
#     'nome': 'Macaé - Rio das Ostras - Cabo Frio'}}},
#  {'id': '3300308',
#   'microrregiao': {'id': 33012,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3305,
#     'nome': 'Sul Fluminense'},
#    'nome': 'Barra do Piraí'},
#   'nome': 'Barra do Piraí',
#   'regiao-imediata': {'id': 330004,
#    'nome': 'Volta Redonda - Barra Mansa',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3302,
#     'nome': 'Volta Redonda - Barra Mansa'}}},
#  {'id': '3300407',
#   'microrregiao': {'id': 33011,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3305,
#     'nome': 'Sul Fluminense'},
#    'nome': 'Vale do Paraíba Fluminense'},
#   'nome': 'Barra Mansa',
#   'regiao-imediata': {'id': 330004,
#    'nome': 'Volta Redonda - Barra Mansa',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3302,
#     'nome': 'Volta Redonda - Barra Mansa'}}},
#  {'id': '3300506',
#   'microrregiao': {'id': 33007,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Centro Fluminense'},
#    'nome': 'Nova Friburgo'},
#   'nome': 'Bom Jardim',
#   'regiao-imediata': {'id': 330008,
#    'nome': 'Nova Friburgo',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Petrópolis'}}},
#  {'id': '3300605',
#   'microrregiao': {'id': 33001,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3301,
#     'nome': 'Noroeste Fluminense'},
#    'nome': 'Itaperuna'},
#   'nome': 'Bom Jesus do Itabapoana',
#   'regiao-imediata': {'id': 330011,
#    'nome': 'Itaperuna',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3304,
#     'nome': 'Campos dos Goytacazes'}}},
#  {'id': '3300704',
#   'microrregiao': {'id': 33010,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3304,
#     'nome': 'Baixadas'},
#    'nome': 'Lagos'},
#   'nome': 'Cabo Frio',
#   'regiao-imediata': {'id': 330013,
#    'nome': 'Cabo Frio',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3305,
#     'nome': 'Macaé - Rio das Ostras - Cabo Frio'}}},
#  {'id': '3300902',
#   'microrregiao': {'id': 33002,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3301,
#     'nome': 'Noroeste Fluminense'},
#    'nome': 'Santo Antônio de Pádua'},
#   'nome': 'Cambuci',
#   'regiao-imediata': {'id': 330012,
#    'nome': 'Santo Antônio de Pádua',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3304,
#     'nome': 'Campos dos Goytacazes'}}},
#  {'id': '3300936',
#   'microrregiao': {'id': 33004,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3302,
#     'nome': 'Norte Fluminense'},
#    'nome': 'Macaé'},
#   'nome': 'Carapebus',
#   'regiao-imediata': {'id': 330014,
#    'nome': 'Macaé - Rio das Ostras',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3305,
#     'nome': 'Macaé - Rio das Ostras - Cabo Frio'}}},
#  {'id': '3300951',
#   'microrregiao': {'id': 33005,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Centro Fluminense'},
#    'nome': 'Três Rios'},
#   'nome': 'Comendador Levy Gasparian',
#   'regiao-imediata': {'id': 330009,
#    'nome': 'Três Rios - Paraíba do Sul',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Petrópolis'}}},
#  {'id': '3301009',
#   'microrregiao': {'id': 33003,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3302,
#     'nome': 'Norte Fluminense'},
#    'nome': 'Campos dos Goytacazes'},
#   'nome': 'Campos dos Goytacazes',
#   'regiao-imediata': {'id': 330010,
#    'nome': 'Campos dos Goytacazes',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3304,
#     'nome': 'Campos dos Goytacazes'}}},
#  {'id': '3301108',
#   'microrregiao': {'id': 33006,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Centro Fluminense'},
#    'nome': 'Cantagalo-Cordeiro'},
#   'nome': 'Cantagalo',
#   'regiao-imediata': {'id': 330008,
#    'nome': 'Nova Friburgo',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Petrópolis'}}},
#  {'id': '3301157',
#   'microrregiao': {'id': 33003,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3302,
#     'nome': 'Norte Fluminense'},
#    'nome': 'Campos dos Goytacazes'},
#   'nome': 'Cardoso Moreira',
#   'regiao-imediata': {'id': 330010,
#    'nome': 'Campos dos Goytacazes',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3304,
#     'nome': 'Campos dos Goytacazes'}}},
#  {'id': '3301207',
#   'microrregiao': {'id': 33006,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Centro Fluminense'},
#    'nome': 'Cantagalo-Cordeiro'},
#   'nome': 'Carmo',
#   'regiao-imediata': {'id': 330008,
#    'nome': 'Nova Friburgo',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Petrópolis'}}},
#  {'id': '3301306',
#   'microrregiao': {'id': 33009,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3304,
#     'nome': 'Baixadas'},
#    'nome': 'Bacia de São João'},
#   'nome': 'Casimiro de Abreu',
#   'regiao-imediata': {'id': 330014,
#    'nome': 'Macaé - Rio das Ostras',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3305,
#     'nome': 'Macaé - Rio das Ostras - Cabo Frio'}}},
#  {'id': '3301405',
#   'microrregiao': {'id': 33004,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3302,
#     'nome': 'Norte Fluminense'},
#    'nome': 'Macaé'},
#   'nome': 'Conceição de Macabu',
#   'regiao-imediata': {'id': 330014,
#    'nome': 'Macaé - Rio das Ostras',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3305,
#     'nome': 'Macaé - Rio das Ostras - Cabo Frio'}}},
#  {'id': '3301504',
#   'microrregiao': {'id': 33006,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Centro Fluminense'},
#    'nome': 'Cantagalo-Cordeiro'},
#   'nome': 'Cordeiro',
#   'regiao-imediata': {'id': 330008,
#    'nome': 'Nova Friburgo',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Petrópolis'}}},
#  {'id': '3301603',
#   'microrregiao': {'id': 33007,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Centro Fluminense'},
#    'nome': 'Nova Friburgo'},
#   'nome': 'Duas Barras',
#   'regiao-imediata': {'id': 330008,
#    'nome': 'Nova Friburgo',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Petrópolis'}}},
#  {'id': '3301801',
#   'microrregiao': {'id': 33014,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3306,
#     'nome': 'Metropolitana do Rio de Janeiro'},
#    'nome': 'Vassouras'},
#   'nome': 'Engenheiro Paulo de Frontin',
#   'regiao-imediata': {'id': 330004,
#    'nome': 'Volta Redonda - Barra Mansa',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3302,
#     'nome': 'Volta Redonda - Barra Mansa'}}},
#  {'id': '3301876',
#   'microrregiao': {'id': 33010,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3304,
#     'nome': 'Baixadas'},
#    'nome': 'Lagos'},
#   'nome': 'Iguaba Grande',
#   'regiao-imediata': {'id': 330013,
#    'nome': 'Cabo Frio',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3305,
#     'nome': 'Macaé - Rio das Ostras - Cabo Frio'}}},
#  {'id': '3302056',
#   'microrregiao': {'id': 33001,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3301,
#     'nome': 'Noroeste Fluminense'},
#    'nome': 'Itaperuna'},
#   'nome': 'Italva',
#   'regiao-imediata': {'id': 330010,
#    'nome': 'Campos dos Goytacazes',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3304,
#     'nome': 'Campos dos Goytacazes'}}},
#  {'id': '3302106',
#   'microrregiao': {'id': 33002,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3301,
#     'nome': 'Noroeste Fluminense'},
#    'nome': 'Santo Antônio de Pádua'},
#   'nome': 'Itaocara',
#   'regiao-imediata': {'id': 330012,
#    'nome': 'Santo Antônio de Pádua',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3304,
#     'nome': 'Campos dos Goytacazes'}}},
#  {'id': '3302205',
#   'microrregiao': {'id': 33001,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3301,
#     'nome': 'Noroeste Fluminense'},
#    'nome': 'Itaperuna'},
#   'nome': 'Itaperuna',
#   'regiao-imediata': {'id': 330011,
#    'nome': 'Itaperuna',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3304,
#     'nome': 'Campos dos Goytacazes'}}},
#  {'id': '3302254',
#   'microrregiao': {'id': 33011,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3305,
#     'nome': 'Sul Fluminense'},
#    'nome': 'Vale do Paraíba Fluminense'},
#   'nome': 'Itatiaia',
#   'regiao-imediata': {'id': 330005,
#    'nome': 'Resende',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3302,
#     'nome': 'Volta Redonda - Barra Mansa'}}},
#  {'id': '3302304',
#   'microrregiao': {'id': 33001,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3301,
#     'nome': 'Noroeste Fluminense'},
#    'nome': 'Itaperuna'},
#   'nome': 'Laje do Muriaé',
#   'regiao-imediata': {'id': 330011,
#    'nome': 'Itaperuna',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3304,
#     'nome': 'Campos dos Goytacazes'}}},
#  {'id': '3302403',
#   'microrregiao': {'id': 33004,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3302,
#     'nome': 'Norte Fluminense'},
#    'nome': 'Macaé'},
#   'nome': 'Macaé',
#   'regiao-imediata': {'id': 330014,
#    'nome': 'Macaé - Rio das Ostras',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3305,
#     'nome': 'Macaé - Rio das Ostras - Cabo Frio'}}},
#  {'id': '3302452',
#   'microrregiao': {'id': 33006,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Centro Fluminense'},
#    'nome': 'Cantagalo-Cordeiro'},
#   'nome': 'Macuco',
#   'regiao-imediata': {'id': 330008,
#    'nome': 'Nova Friburgo',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Petrópolis'}}},
#  {'id': '3302809',
#   'microrregiao': {'id': 33014,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3306,
#     'nome': 'Metropolitana do Rio de Janeiro'},
#    'nome': 'Vassouras'},
#   'nome': 'Mendes',
#   'regiao-imediata': {'id': 330004,
#    'nome': 'Volta Redonda - Barra Mansa',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3302,
#     'nome': 'Volta Redonda - Barra Mansa'}}},
#  {'id': '3302908',
#   'microrregiao': {'id': 33014,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3306,
#     'nome': 'Metropolitana do Rio de Janeiro'},
#    'nome': 'Vassouras'},
#   'nome': 'Miguel Pereira',
#   'regiao-imediata': {'id': 330006,
#    'nome': 'Valença',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3302,
#     'nome': 'Volta Redonda - Barra Mansa'}}},
#  {'id': '3303005',
#   'microrregiao': {'id': 33002,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3301,
#     'nome': 'Noroeste Fluminense'},
#    'nome': 'Santo Antônio de Pádua'},
#   'nome': 'Miracema',
#   'regiao-imediata': {'id': 330012,
#    'nome': 'Santo Antônio de Pádua',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3304,
#     'nome': 'Campos dos Goytacazes'}}},
#  {'id': '3303104',
#   'microrregiao': {'id': 33001,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3301,
#     'nome': 'Noroeste Fluminense'},
#    'nome': 'Itaperuna'},
#   'nome': 'Natividade',
#   'regiao-imediata': {'id': 330011,
#    'nome': 'Itaperuna',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3304,
#     'nome': 'Campos dos Goytacazes'}}},
#  {'id': '3303401',
#   'microrregiao': {'id': 33007,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Centro Fluminense'},
#    'nome': 'Nova Friburgo'},
#   'nome': 'Nova Friburgo',
#   'regiao-imediata': {'id': 330008,
#    'nome': 'Nova Friburgo',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Petrópolis'}}},
#  {'id': '3303609',
#   'microrregiao': {'id': 33014,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3306,
#     'nome': 'Metropolitana do Rio de Janeiro'},
#    'nome': 'Vassouras'},
#   'nome': 'Paracambi',
#   'regiao-imediata': {'id': 330001,
#    'nome': 'Rio de Janeiro',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3301,
#     'nome': 'Rio de Janeiro'}}},
#  {'id': '3303708',
#   'microrregiao': {'id': 33005,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Centro Fluminense'},
#    'nome': 'Três Rios'},
#   'nome': 'Paraíba do Sul',
#   'regiao-imediata': {'id': 330009,
#    'nome': 'Três Rios - Paraíba do Sul',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Petrópolis'}}},
#  {'id': '3303807',
#   'microrregiao': {'id': 33013,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3305,
#     'nome': 'Sul Fluminense'},
#    'nome': 'Baía da Ilha Grande'},
#   'nome': 'Paraty',
#   'regiao-imediata': {'id': 330002,
#    'nome': 'Angra dos Reis',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3301,
#     'nome': 'Rio de Janeiro'}}},
#  {'id': '3303856',
#   'microrregiao': {'id': 33014,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3306,
#     'nome': 'Metropolitana do Rio de Janeiro'},
#    'nome': 'Vassouras'},
#   'nome': 'Paty do Alferes',
#   'regiao-imediata': {'id': 330006,
#    'nome': 'Valença',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3302,
#     'nome': 'Volta Redonda - Barra Mansa'}}},
#  {'id': '3303955',
#   'microrregiao': {'id': 33011,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3305,
#     'nome': 'Sul Fluminense'},
#    'nome': 'Vale do Paraíba Fluminense'},
#   'nome': 'Pinheiral',
#   'regiao-imediata': {'id': 330004,
#    'nome': 'Volta Redonda - Barra Mansa',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3302,
#     'nome': 'Volta Redonda - Barra Mansa'}}},
#  {'id': '3304003',
#   'microrregiao': {'id': 33011,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3305,
#     'nome': 'Sul Fluminense'},
#    'nome': 'Vale do Paraíba Fluminense'},
#   'nome': 'Piraí',
#   'regiao-imediata': {'id': 330004,
#    'nome': 'Volta Redonda - Barra Mansa',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3302,
#     'nome': 'Volta Redonda - Barra Mansa'}}},
#  {'id': '3304102',
#   'microrregiao': {'id': 33001,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3301,
#     'nome': 'Noroeste Fluminense'},
#    'nome': 'Itaperuna'},
#   'nome': 'Porciúncula',
#   'regiao-imediata': {'id': 330011,
#    'nome': 'Itaperuna',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3304,
#     'nome': 'Campos dos Goytacazes'}}},
#  {'id': '3304110',
#   'microrregiao': {'id': 33011,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3305,
#     'nome': 'Sul Fluminense'},
#    'nome': 'Vale do Paraíba Fluminense'},
#   'nome': 'Porto Real',
#   'regiao-imediata': {'id': 330005,
#    'nome': 'Resende',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3302,
#     'nome': 'Volta Redonda - Barra Mansa'}}},
#  {'id': '3304128',
#   'microrregiao': {'id': 33011,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3305,
#     'nome': 'Sul Fluminense'},
#    'nome': 'Vale do Paraíba Fluminense'},
#   'nome': 'Quatis',
#   'regiao-imediata': {'id': 330005,
#    'nome': 'Resende',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3302,
#     'nome': 'Volta Redonda - Barra Mansa'}}},
#  {'id': '3304151',
#   'microrregiao': {'id': 33004,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3302,
#     'nome': 'Norte Fluminense'},
#    'nome': 'Macaé'},
#   'nome': 'Quissamã',
#   'regiao-imediata': {'id': 330014,
#    'nome': 'Macaé - Rio das Ostras',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3305,
#     'nome': 'Macaé - Rio das Ostras - Cabo Frio'}}},
#  {'id': '3304201',
#   'microrregiao': {'id': 33011,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3305,
#     'nome': 'Sul Fluminense'},
#    'nome': 'Vale do Paraíba Fluminense'},
#   'nome': 'Resende',
#   'regiao-imediata': {'id': 330005,
#    'nome': 'Resende',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3302,
#     'nome': 'Volta Redonda - Barra Mansa'}}},
#  {'id': '3304409',
#   'microrregiao': {'id': 33011,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3305,
#     'nome': 'Sul Fluminense'},
#    'nome': 'Vale do Paraíba Fluminense'},
#   'nome': 'Rio Claro',
#   'regiao-imediata': {'id': 330004,
#    'nome': 'Volta Redonda - Barra Mansa',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3302,
#     'nome': 'Volta Redonda - Barra Mansa'}}},
#  {'id': '3304508',
#   'microrregiao': {'id': 33012,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3305,
#     'nome': 'Sul Fluminense'},
#    'nome': 'Barra do Piraí'},
#   'nome': 'Rio das Flores',
#   'regiao-imediata': {'id': 330006,
#    'nome': 'Valença',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3302,
#     'nome': 'Volta Redonda - Barra Mansa'}}},
#  {'id': '3304524',
#   'microrregiao': {'id': 33009,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3304,
#     'nome': 'Baixadas'},
#    'nome': 'Bacia de São João'},
#   'nome': 'Rio das Ostras',
#   'regiao-imediata': {'id': 330014,
#    'nome': 'Macaé - Rio das Ostras',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3305,
#     'nome': 'Macaé - Rio das Ostras - Cabo Frio'}}},
#  {'id': '3304607',
#   'microrregiao': {'id': 33008,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Centro Fluminense'},
#    'nome': 'Santa Maria Madalena'},
#   'nome': 'Santa Maria Madalena',
#   'regiao-imediata': {'id': 330008,
#    'nome': 'Nova Friburgo',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Petrópolis'}}},
#  {'id': '3304706',
#   'microrregiao': {'id': 33002,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3301,
#     'nome': 'Noroeste Fluminense'},
#    'nome': 'Santo Antônio de Pádua'},
#   'nome': 'Santo Antônio de Pádua',
#   'regiao-imediata': {'id': 330012,
#    'nome': 'Santo Antônio de Pádua',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3304,
#     'nome': 'Campos dos Goytacazes'}}},
#  {'id': '3304755',
#   'microrregiao': {'id': 33003,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3302,
#     'nome': 'Norte Fluminense'},
#    'nome': 'Campos dos Goytacazes'},
#   'nome': 'São Francisco de Itabapoana',
#   'regiao-imediata': {'id': 330010,
#    'nome': 'Campos dos Goytacazes',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3304,
#     'nome': 'Campos dos Goytacazes'}}},
#  {'id': '3304805',
#   'microrregiao': {'id': 33003,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3302,
#     'nome': 'Norte Fluminense'},
#    'nome': 'Campos dos Goytacazes'},
#   'nome': 'São Fidélis',
#   'regiao-imediata': {'id': 330010,
#    'nome': 'Campos dos Goytacazes',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3304,
#     'nome': 'Campos dos Goytacazes'}}},
#  {'id': '3305000',
#   'microrregiao': {'id': 33003,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3302,
#     'nome': 'Norte Fluminense'},
#    'nome': 'Campos dos Goytacazes'},
#   'nome': 'São João da Barra',
#   'regiao-imediata': {'id': 330010,
#    'nome': 'Campos dos Goytacazes',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3304,
#     'nome': 'Campos dos Goytacazes'}}},
#  {'id': '3305133',
#   'microrregiao': {'id': 33002,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3301,
#     'nome': 'Noroeste Fluminense'},
#    'nome': 'Santo Antônio de Pádua'},
#   'nome': 'São José de Ubá',
#   'regiao-imediata': {'id': 330011,
#    'nome': 'Itaperuna',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3304,
#     'nome': 'Campos dos Goytacazes'}}},
#  {'id': '3305208',
#   'microrregiao': {'id': 33010,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3304,
#     'nome': 'Baixadas'},
#    'nome': 'Lagos'},
#   'nome': 'São Pedro da Aldeia',
#   'regiao-imediata': {'id': 330013,
#    'nome': 'Cabo Frio',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3305,
#     'nome': 'Macaé - Rio das Ostras - Cabo Frio'}}},
#  {'id': '3305307',
#   'microrregiao': {'id': 33008,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Centro Fluminense'},
#    'nome': 'Santa Maria Madalena'},
#   'nome': 'São Sebastião do Alto',
#   'regiao-imediata': {'id': 330008,
#    'nome': 'Nova Friburgo',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Petrópolis'}}},
#  {'id': '3305406',
#   'microrregiao': {'id': 33005,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Centro Fluminense'},
#    'nome': 'Três Rios'},
#   'nome': 'Sapucaia',
#   'regiao-imediata': {'id': 330009,
#    'nome': 'Três Rios - Paraíba do Sul',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Petrópolis'}}},
#  {'id': '3305505',
#   'microrregiao': {'id': 33010,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3304,
#     'nome': 'Baixadas'},
#    'nome': 'Lagos'},
#   'nome': 'Saquarema',
#   'regiao-imediata': {'id': 330001,
#    'nome': 'Rio de Janeiro',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3301,
#     'nome': 'Rio de Janeiro'}}},
#  {'id': '3305604',
#   'microrregiao': {'id': 33009,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3304,
#     'nome': 'Baixadas'},
#    'nome': 'Bacia de São João'},
#   'nome': 'Silva Jardim',
#   'regiao-imediata': {'id': 330003,
#    'nome': 'Rio Bonito',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3301,
#     'nome': 'Rio de Janeiro'}}},
#  {'id': '3305703',
#   'microrregiao': {'id': 33007,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Centro Fluminense'},
#    'nome': 'Nova Friburgo'},
#   'nome': 'Sumidouro',
#   'regiao-imediata': {'id': 330008,
#    'nome': 'Nova Friburgo',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Petrópolis'}}},
#  {'id': '3305901',
#   'microrregiao': {'id': 33008,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Centro Fluminense'},
#    'nome': 'Santa Maria Madalena'},
#   'nome': 'Trajano de Moraes',
#   'regiao-imediata': {'id': 330008,
#    'nome': 'Nova Friburgo',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Petrópolis'}}},
#  {'id': '3306008',
#   'microrregiao': {'id': 33005,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Centro Fluminense'},
#    'nome': 'Três Rios'},
#   'nome': 'Três Rios',
#   'regiao-imediata': {'id': 330009,
#    'nome': 'Três Rios - Paraíba do Sul',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3303,
#     'nome': 'Petrópolis'}}},
#  {'id': '3306107',
#   'microrregiao': {'id': 33012,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3305,
#     'nome': 'Sul Fluminense'},
#    'nome': 'Barra do Piraí'},
#   'nome': 'Valença',
#   'regiao-imediata': {'id': 330006,
#    'nome': 'Valença',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3302,
#     'nome': 'Volta Redonda - Barra Mansa'}}},
#  {'id': '3306156',
#   'microrregiao': {'id': 33001,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3301,
#     'nome': 'Noroeste Fluminense'},
#    'nome': 'Itaperuna'},
#   'nome': 'Varre-Sai',
#   'regiao-imediata': {'id': 330011,
#    'nome': 'Itaperuna',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3304,
#     'nome': 'Campos dos Goytacazes'}}},
#  {'id': '3306206',
#   'microrregiao': {'id': 33014,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3306,
#     'nome': 'Metropolitana do Rio de Janeiro'},
#    'nome': 'Vassouras'},
#   'nome': 'Vassouras',
#   'regiao-imediata': {'id': 330006,
#    'nome': 'Valença',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3302,
#     'nome': 'Volta Redonda - Barra Mansa'}}},
#  {'id': '3306305',
#   'microrregiao': {'id': 33011,
#    'mesorregiao': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3305,
#     'nome': 'Sul Fluminense'},
#    'nome': 'Vale do Paraíba Fluminense'},
#   'nome': 'Volta Redonda',
#   'regiao-imediata': {'id': 330004,
#    'nome': 'Volta Redonda - Barra Mansa',
#    'regiao-intermediaria': {'UF': {'id': 33,
#      'nome': 'Rio de Janeiro',
#      'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#      'sigla': 'RJ'},
#     'id': 3302,
#     'nome': 'Volta Redonda - Barra Mansa'}}}]

# %%
# Criar Dataframe com todas as cidades
df = spark.read.json(sc.parallelize(data))
df.show(n=68)
# Out:
# +-------+--------------------+--------------------+--------------------+
# |     id|        microrregiao|                nome|     regiao-imediata|
# +-------+--------------------+--------------------+--------------------+
# |3300100|{33013, {{33, Rio...|      Angra dos Reis|{330002, Angra do...|
# |3300159|{33002, {{33, Rio...|             Aperibé|{330012, Santo An...|
# |3300209|{33010, {{33, Rio...|            Araruama|{330013, Cabo Fri...|
# |3300225|{33005, {{33, Rio...|               Areal|{330007, Petrópol...|
# |3300233|{33010, {{33, Rio...|  Armação dos Búzios|{330013, Cabo Fri...|
# |3300258|{33010, {{33, Rio...|     Arraial do Cabo|{330013, Cabo Fri...|
# |3300308|{33012, {{33, Rio...|      Barra do Piraí|{330004, Volta Re...|
# |3300407|{33011, {{33, Rio...|         Barra Mansa|{330004, Volta Re...|
# |3300506|{33007, {{33, Rio...|          Bom Jardim|{330008, Nova Fri...|
# |3300605|{33001, {{33, Rio...|Bom Jesus do Itab...|{330011, Itaperun...|
# |3300704|{33010, {{33, Rio...|           Cabo Frio|{330013, Cabo Fri...|
# |3300902|{33002, {{33, Rio...|             Cambuci|{330012, Santo An...|
# |3300936|{33004, {{33, Rio...|           Carapebus|{330014, Macaé - ...|
# |3300951|{33005, {{33, Rio...|Comendador Levy G...|{330009, Três Rio...|
# |3301009|{33003, {{33, Rio...|Campos dos Goytac...|{330010, Campos d...|
# |3301108|{33006, {{33, Rio...|           Cantagalo|{330008, Nova Fri...|
# |3301157|{33003, {{33, Rio...|     Cardoso Moreira|{330010, Campos d...|
# |3301207|{33006, {{33, Rio...|               Carmo|{330008, Nova Fri...|
# |3301306|{33009, {{33, Rio...|   Casimiro de Abreu|{330014, Macaé - ...|
# |3301405|{33004, {{33, Rio...| Conceição de Macabu|{330014, Macaé - ...|
# |3301504|{33006, {{33, Rio...|            Cordeiro|{330008, Nova Fri...|
# |3301603|{33007, {{33, Rio...|         Duas Barras|{330008, Nova Fri...|
# |3301801|{33014, {{33, Rio...|Engenheiro Paulo ...|{330004, Volta Re...|
# |3301876|{33010, {{33, Rio...|       Iguaba Grande|{330013, Cabo Fri...|
# |3302056|{33001, {{33, Rio...|              Italva|{330010, Campos d...|
# |3302106|{33002, {{33, Rio...|            Itaocara|{330012, Santo An...|
# |3302205|{33001, {{33, Rio...|           Itaperuna|{330011, Itaperun...|
# |3302254|{33011, {{33, Rio...|            Itatiaia|{330005, Resende,...|
# |3302304|{33001, {{33, Rio...|      Laje do Muriaé|{330011, Itaperun...|
# |3302403|{33004, {{33, Rio...|               Macaé|{330014, Macaé - ...|
# |3302452|{33006, {{33, Rio...|              Macuco|{330008, Nova Fri...|
# |3302809|{33014, {{33, Rio...|              Mendes|{330004, Volta Re...|
# |3302908|{33014, {{33, Rio...|      Miguel Pereira|{330006, Valença,...|
# |3303005|{33002, {{33, Rio...|            Miracema|{330012, Santo An...|
# |3303104|{33001, {{33, Rio...|          Natividade|{330011, Itaperun...|
# |3303401|{33007, {{33, Rio...|       Nova Friburgo|{330008, Nova Fri...|
# |3303609|{33014, {{33, Rio...|           Paracambi|{330001, Rio de J...|
# |3303708|{33005, {{33, Rio...|      Paraíba do Sul|{330009, Três Rio...|
# |3303807|{33013, {{33, Rio...|              Paraty|{330002, Angra do...|
# |3303856|{33014, {{33, Rio...|     Paty do Alferes|{330006, Valença,...|
# |3303955|{33011, {{33, Rio...|           Pinheiral|{330004, Volta Re...|
# |3304003|{33011, {{33, Rio...|               Piraí|{330004, Volta Re...|
# |3304102|{33001, {{33, Rio...|         Porciúncula|{330011, Itaperun...|
# |3304110|{33011, {{33, Rio...|          Porto Real|{330005, Resende,...|
# |3304128|{33011, {{33, Rio...|              Quatis|{330005, Resende,...|
# |3304151|{33004, {{33, Rio...|            Quissamã|{330014, Macaé - ...|
# |3304201|{33011, {{33, Rio...|             Resende|{330005, Resende,...|
# |3304409|{33011, {{33, Rio...|           Rio Claro|{330004, Volta Re...|
# |3304508|{33012, {{33, Rio...|      Rio das Flores|{330006, Valença,...|
# |3304524|{33009, {{33, Rio...|      Rio das Ostras|{330014, Macaé - ...|
# |3304607|{33008, {{33, Rio...|Santa Maria Madalena|{330008, Nova Fri...|
# |3304706|{33002, {{33, Rio...|Santo Antônio de ...|{330012, Santo An...|
# |3304755|{33003, {{33, Rio...|São Francisco de ...|{330010, Campos d...|
# |3304805|{33003, {{33, Rio...|         São Fidélis|{330010, Campos d...|
# |3305000|{33003, {{33, Rio...|   São João da Barra|{330010, Campos d...|
# |3305133|{33002, {{33, Rio...|     São José de Ubá|{330011, Itaperun...|
# |3305208|{33010, {{33, Rio...| São Pedro da Aldeia|{330013, Cabo Fri...|
# |3305307|{33008, {{33, Rio...|São Sebastião do ...|{330008, Nova Fri...|
# |3305406|{33005, {{33, Rio...|            Sapucaia|{330009, Três Rio...|
# |3305505|{33010, {{33, Rio...|           Saquarema|{330001, Rio de J...|
# |3305604|{33009, {{33, Rio...|        Silva Jardim|{330003, Rio Boni...|
# |3305703|{33007, {{33, Rio...|           Sumidouro|{330008, Nova Fri...|
# |3305901|{33008, {{33, Rio...|   Trajano de Moraes|{330008, Nova Fri...|
# |3306008|{33005, {{33, Rio...|           Três Rios|{330009, Três Rio...|
# |3306107|{33012, {{33, Rio...|             Valença|{330006, Valença,...|
# |3306156|{33001, {{33, Rio...|           Varre-Sai|{330011, Itaperun...|
# |3306206|{33014, {{33, Rio...|           Vassouras|{330006, Valença,...|
# |3306305|{33011, {{33, Rio...|       Volta Redonda|{330004, Volta Re...|
# +-------+--------------------+--------------------+--------------------+

# %%
# visualizando o schema
df.printSchema()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- microrregiao: struct (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- mesorregiao: struct (nullable = true)
#  |    |    |-- UF: struct (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- nome: string (nullable = true)
#  |    |    |    |-- regiao: struct (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- nome: string (nullable = true)
#  |    |    |    |    |-- sigla: string (nullable = true)
#  |    |    |    |-- sigla: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- nome: string (nullable = true)
#  |    |-- nome: string (nullable = true)
#  |-- nome: string (nullable = true)
#  |-- regiao-imediata: struct (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- nome: string (nullable = true)
#  |    |-- regiao-intermediaria: struct (nullable = true)
#  |    |    |-- UF: struct (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- nome: string (nullable = true)
#  |    |    |    |-- regiao: struct (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- nome: string (nullable = true)
#  |    |    |    |    |-- sigla: string (nullable = true)
#  |    |    |    |-- sigla: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- nome: string (nullable = true)

# %%
# Criar view com as cidades
df.createOrReplaceTempView("cities")

# %%
# Extrai nomes das cidades em uma lista para passar para a API de previsão do tempo
nomes_cidades = df.select("nome").rdd.flatMap(lambda x: x).collect()
nomes_cidades
# Out:
# ['Angra dos Reis',
#  'Aperibé',
#  'Araruama',
#  'Areal',
#  'Armação dos Búzios',
#  'Arraial do Cabo',
#  'Barra do Piraí',
#  'Barra Mansa',
#  'Bom Jardim',
#  'Bom Jesus do Itabapoana',
#  'Cabo Frio',
#  'Cambuci',
#  'Carapebus',
#  'Comendador Levy Gasparian',
#  'Campos dos Goytacazes',
#  'Cantagalo',
#  'Cardoso Moreira',
#  'Carmo',
#  'Casimiro de Abreu',
#  'Conceição de Macabu',
#  'Cordeiro',
#  'Duas Barras',
#  'Engenheiro Paulo de Frontin',
#  'Iguaba Grande',
#  'Italva',
#  'Itaocara',
#  'Itaperuna',
#  'Itatiaia',
#  'Laje do Muriaé',
#  'Macaé',
#  'Macuco',
#  'Mendes',
#  'Miguel Pereira',
#  'Miracema',
#  'Natividade',
#  'Nova Friburgo',
#  'Paracambi',
#  'Paraíba do Sul',
#  'Paraty',
#  'Paty do Alferes',
#  'Pinheiral',
#  'Piraí',
#  'Porciúncula',
#  'Porto Real',
#  'Quatis',
#  'Quissamã',
#  'Resende',
#  'Rio Claro',
#  'Rio das Flores',
#  'Rio das Ostras',
#  'Santa Maria Madalena',
#  'Santo Antônio de Pádua',
#  'São Francisco de Itabapoana',
#  'São Fidélis',
#  'São João da Barra',
#  'São José de Ubá',
#  'São Pedro da Aldeia',
#  'São Sebastião do Alto',
#  'Sapucaia',
#  'Saquarema',
#  'Silva Jardim',
#  'Sumidouro',
#  'Trajano de Moraes',
#  'Três Rios',
#  'Valença',
#  'Varre-Sai',
#  'Vassouras',
#  'Volta Redonda']

# %%
# verificar quantas cidades
len(nomes_cidades)
# Out:
# 68

# %%
# Buscar as previsões na API da WeatherAPI
lista_previsoes = []
datas = ["2022-07-13", "2022-07-14", "2022-07-15", "2022-07-16", "2022-07-17"]

for cidade in nomes_cidades:
  api_key = "27b873d37ea2471385912343220707"
  
  for dt in datas:
    link = f"http://api.weatherapi.com/v1/history.json?key={api_key}&q={cidade}&dt={dt}&hour=12"

    requisicao = requests.get(link)
    requisicao_dic = requisicao.json()
    lista_previsoes.append(requisicao_dic)

# %%
# Verificar se retornou 5 previsões por cidade (5 * 68)
len(lista_previsoes)
# Out:
# 340

# %%
# Criar Dataframe com as previsões
df_previsoes = spark.read.json(sc.parallelize(lista_previsoes))
df_previsoes.show()
# Out:
# +--------------------+--------------------+--------------------+
# |               error|            forecast|            location|
# +--------------------+--------------------+--------------------+
# |                null|{[{{97, Waxing Gi...|{Brazil, -23.0, 2...|
# |                null|{[{{97, Full Moon...|{Brazil, -23.0, 2...|
# |                null|{[{{90, Full Moon...|{Brazil, -23.0, 2...|
# |                null|{[{{83, Full Moon...|{Brazil, -23.0, 2...|
# |                null|{[{{76, Full Moon...|{Brazil, -23.0, 2...|
# |{1006, No matchin...|                null|                null|
# |{1006, No matchin...|                null|                null|
# |{1006, No matchin...|                null|                null|
# |{1006, No matchin...|                null|                null|
# |{1006, No matchin...|                null|                null|
# |                null|{[{{97, Waxing Gi...|{Brazil, -22.88, ...|
# |                null|{[{{97, Full Moon...|{Brazil, -22.88, ...|
# |                null|{[{{90, Full Moon...|{Brazil, -22.88, ...|
# |                null|{[{{83, Full Moon...|{Brazil, -22.88, ...|
# |                null|{[{{76, Full Moon...|{Brazil, -22.88, ...|
# |                null|{[{{97, Waxing Gi...|{Brazil, -22.23, ...|
# |                null|{[{{97, Full Moon...|{Brazil, -22.23, ...|
# |                null|{[{{90, Full Moon...|{Brazil, -22.23, ...|
# |                null|{[{{83, Full Moon...|{Brazil, -22.23, ...|
# |                null|{[{{76, Full Moon...|{Brazil, -22.23, ...|
# +--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
# Criar view com as previsões
df_previsoes.createOrReplaceTempView("forecasts")

# %%
# Verificar schema do Dataframe das previsões
df_previsoes.printSchema()
# Out:
# root
#  |-- error: struct (nullable = true)
#  |    |-- code: long (nullable = true)
#  |    |-- message: string (nullable = true)
#  |-- forecast: struct (nullable = true)
#  |    |-- forecastday: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- astro: struct (nullable = true)
#  |    |    |    |    |-- moon_illumination: string (nullable = true)
#  |    |    |    |    |-- moon_phase: string (nullable = true)
#  |    |    |    |    |-- moonrise: string (nullable = true)
#  |    |    |    |    |-- moonset: string (nullable = true)
#  |    |    |    |    |-- sunrise: string (nullable = true)
#  |    |    |    |    |-- sunset: string (nullable = true)
#  |    |    |    |-- date: string (nullable = true)
#  |    |    |    |-- date_epoch: long (nullable = true)
#  |    |    |    |-- day: struct (nullable = true)
#  |    |    |    |    |-- avghumidity: double (nullable = true)
#  |    |    |    |    |-- avgtemp_c: double (nullable = true)
#  |    |    |    |    |-- avgtemp_f: double (nullable = true)
#  |    |    |    |    |-- avgvis_km: double (nullable = true)
#  |    |    |    |    |-- avgvis_miles: double (nullable = true)
#  |    |    |    |    |-- condition: struct (nullable = true)
#  |    |    |    |    |    |-- code: long (nullable = true)
#  |    |    |    |    |    |-- icon: string (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |-- maxtemp_c: double (nullable = true)
#  |    |    |    |    |-- maxtemp_f: double (nullable = true)
#  |    |    |    |    |-- maxwind_kph: double (nullable = true)
#  |    |    |    |    |-- maxwind_mph: double (nullable = true)
#  |    |    |    |    |-- mintemp_c: double (nullable = true)
#  |    |    |    |    |-- mintemp_f: double (nullable = true)
#  |    |    |    |    |-- totalprecip_in: double (nullable = true)
#  |    |    |    |    |-- totalprecip_mm: double (nullable = true)
#  |    |    |    |    |-- uv: double (nullable = true)
#  |    |    |    |-- hour: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- chance_of_rain: long (nullable = true)
#  |    |    |    |    |    |-- chance_of_snow: long (nullable = true)
#  |    |    |    |    |    |-- cloud: long (nullable = true)
#  |    |    |    |    |    |-- condition: struct (nullable = true)
#  |    |    |    |    |    |    |-- code: long (nullable = true)
#  |    |    |    |    |    |    |-- icon: string (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- dewpoint_c: double (nullable = true)
#  |    |    |    |    |    |-- dewpoint_f: double (nullable = true)
#  |    |    |    |    |    |-- feelslike_c: double (nullable = true)
#  |    |    |    |    |    |-- feelslike_f: double (nullable = true)
#  |    |    |    |    |    |-- gust_kph: double (nullable = true)
#  |    |    |    |    |    |-- gust_mph: double (nullable = true)
#  |    |    |    |    |    |-- heatindex_c: double (nullable = true)
#  |    |    |    |    |    |-- heatindex_f: double (nullable = true)
#  |    |    |    |    |    |-- humidity: long (nullable = true)
#  |    |    |    |    |    |-- is_day: long (nullable = true)
#  |    |    |    |    |    |-- precip_in: double (nullable = true)
#  |    |    |    |    |    |-- precip_mm: double (nullable = true)
#  |    |    |    |    |    |-- pressure_in: double (nullable = true)
#  |    |    |    |    |    |-- pressure_mb: double (nullable = true)
#  |    |    |    |    |    |-- temp_c: double (nullable = true)
#  |    |    |    |    |    |-- temp_f: double (nullable = true)
#  |    |    |    |    |    |-- time: string (nullable = true)
#  |    |    |    |    |    |-- time_epoch: long (nullable = true)
#  |    |    |    |    |    |-- vis_km: double (nullable = true)
#  |    |    |    |    |    |-- vis_miles: double (nullable = true)
#  |    |    |    |    |    |-- will_it_rain: long (nullable = true)
#  |    |    |    |    |    |-- will_it_snow: long (nullable = true)
#  |    |    |    |    |    |-- wind_degree: long (nullable = true)
#  |    |    |    |    |    |-- wind_dir: string (nullable = true)
#  |    |    |    |    |    |-- wind_kph: double (nullable = true)
#  |    |    |    |    |    |-- wind_mph: double (nullable = true)
#  |    |    |    |    |    |-- windchill_c: double (nullable = true)
#  |    |    |    |    |    |-- windchill_f: double (nullable = true)
#  |-- location: struct (nullable = true)
#  |    |-- country: string (nullable = true)
#  |    |-- lat: double (nullable = true)
#  |    |-- localtime: string (nullable = true)
#  |    |-- localtime_epoch: long (nullable = true)
#  |    |-- lon: double (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- region: string (nullable = true)
#  |    |-- tz_id: string (nullable = true)

# %%
# Criar DF da Tabela 1
df_1 = spark.sql("""SELECT
                    A.nome as cidade,
                    A.id as codigo_da_cidade,
                    B.location.region as regiao,
                    B.forecast.forecastday[0].date as data,
                    B.location.country as pais,
                    B.location.lat as latitude,
                    B.location.lon as longitude,
                    B.forecast.forecastday[0].day.maxtemp_c as temperatura_maxima,
                    B.forecast.forecastday[0].day.mintemp_c as temperatura_minima,
                    B.forecast.forecastday[0].day.maxtemp_c as temperatura_media,
                    CASE WHEN B.forecast.forecastday[0].hour[0].will_it_rain = 0 THEN 'nao'
                    ELSE 'sim' END AS vai_chover,
                    B.forecast.forecastday[0].hour[0].chance_of_rain as chance_de_chuva,
                    B.forecast.forecastday[0].day.condition.text as condicao_do_tempo,
                    B.forecast.forecastday[0].astro.sunrise as nascer_do_sol,
                    B.forecast.forecastday[0].astro.sunset as por_do_sol,
                    B.forecast.forecastday[0].day.maxwind_kph as velocidade_max_vento

                  FROM cities as A
                  INNER JOIN forecasts as B
                  ON A.nome = B.location.name
                  WHERE B.location.region ='Rio de Janeiro'
                  """)

# %%
# Visualizar df_1
df_1.show()
# Out:
# +-----------+----------------+--------------+----------+------+--------+---------+------------------+------------------+-----------------+----------+---------------+--------------------+-------------+----------+--------------------+
# |     cidade|codigo_da_cidade|        regiao|      data|  pais|latitude|longitude|temperatura_maxima|temperatura_minima|temperatura_media|vai_chover|chance_de_chuva|   condicao_do_tempo|nascer_do_sol|por_do_sol|velocidade_max_vento|
# +-----------+----------------+--------------+----------+------+--------+---------+------------------+------------------+-----------------+----------+---------------+--------------------+-------------+----------+--------------------+
# |   Araruama|         3300209|Rio de Janeiro|2022-07-13|Brazil|  -22.88|   -42.33|              23.7|              19.8|             23.7|       nao|              0|Patchy rain possible|     06:30 AM|  05:21 PM|                26.3|
# |   Araruama|         3300209|Rio de Janeiro|2022-07-14|Brazil|  -22.88|   -42.33|              28.8|              18.6|             28.8|       nao|              0|                Mist|     06:30 AM|  05:21 PM|                29.9|
# |   Araruama|         3300209|Rio de Janeiro|2022-07-15|Brazil|  -22.88|   -42.33|              31.7|              19.4|             31.7|       nao|              0|               Sunny|     06:29 AM|  05:21 PM|                28.8|
# |   Araruama|         3300209|Rio de Janeiro|2022-07-16|Brazil|  -22.88|   -42.33|              31.6|              18.4|             31.6|       nao|              0|               Sunny|     06:29 AM|  05:22 PM|                23.4|
# |   Araruama|         3300209|Rio de Janeiro|2022-07-17|Brazil|  -22.88|   -42.33|              33.5|              20.0|             33.5|       nao|              0|            Overcast|     06:29 AM|  05:22 PM|                24.8|
# |     Paraty|         3303807|Rio de Janeiro|2022-07-13|Brazil|  -23.22|   -44.72|              19.6|              13.2|             19.6|       nao|              0|                Mist|     06:40 AM|  05:30 PM|                 9.0|
# |     Paraty|         3303807|Rio de Janeiro|2022-07-14|Brazil|  -23.22|   -44.72|              25.1|              11.9|             25.1|       nao|              0|                Mist|     06:40 AM|  05:30 PM|                 7.6|
# |     Paraty|         3303807|Rio de Janeiro|2022-07-15|Brazil|  -23.22|   -44.72|              28.4|              13.6|             28.4|       nao|              0|               Sunny|     06:40 AM|  05:30 PM|                12.6|
# |     Paraty|         3303807|Rio de Janeiro|2022-07-16|Brazil|  -23.22|   -44.72|              29.5|              15.1|             29.5|       nao|              0|               Sunny|     06:39 AM|  05:31 PM|                10.4|
# |     Paraty|         3303807|Rio de Janeiro|2022-07-17|Brazil|  -23.22|   -44.72|              30.6|              14.7|             30.6|       nao|              0|       Partly cloudy|     06:39 AM|  05:31 PM|                10.4|
# |Barra Mansa|         3300407|Rio de Janeiro|2022-07-13|Brazil|  -22.53|   -44.18|              22.9|              13.7|             22.9|       nao|              0|                Mist|     06:37 AM|  05:29 PM|                10.4|
# |Barra Mansa|         3300407|Rio de Janeiro|2022-07-14|Brazil|  -22.53|   -44.18|              30.3|              15.8|             30.3|       nao|              0|              Cloudy|     06:36 AM|  05:29 PM|                11.2|
# |Barra Mansa|         3300407|Rio de Janeiro|2022-07-15|Brazil|  -22.53|   -44.18|              32.2|              14.2|             32.2|       nao|              0|               Sunny|     06:36 AM|  05:30 PM|                 7.2|
# |Barra Mansa|         3300407|Rio de Janeiro|2022-07-16|Brazil|  -22.53|   -44.18|              32.3|              13.0|             32.3|       nao|              0|               Sunny|     06:36 AM|  05:30 PM|                 3.6|
# |Barra Mansa|         3300407|Rio de Janeiro|2022-07-17|Brazil|  -22.53|   -44.18|              35.0|              15.0|             35.0|       nao|              0|       Partly cloudy|     06:36 AM|  05:30 PM|                10.4|
# | Porto Real|         3304110|Rio de Janeiro|2022-07-13|Brazil|  -22.42|   -44.33|              21.6|              14.5|             21.6|       nao|              0|              Cloudy|     06:37 AM|  05:30 PM|                10.4|
# | Porto Real|         3304110|Rio de Janeiro|2022-07-14|Brazil|  -22.42|   -44.33|              23.5|              13.8|             23.5|       nao|              0|                Mist|     06:37 AM|  05:30 PM|                10.1|
# | Porto Real|         3304110|Rio de Janeiro|2022-07-15|Brazil|  -22.42|   -44.33|              28.6|              14.3|             28.6|       nao|              0|               Sunny|     06:37 AM|  05:30 PM|                 5.8|
# | Porto Real|         3304110|Rio de Janeiro|2022-07-16|Brazil|  -22.42|   -44.33|              28.2|              15.5|             28.2|       nao|              0|               Sunny|     06:36 AM|  05:31 PM|                 5.8|
# | Porto Real|         3304110|Rio de Janeiro|2022-07-17|Brazil|  -22.42|   -44.33|              31.2|              15.3|             31.2|       nao|              0|       Partly cloudy|     06:36 AM|  05:31 PM|                 9.4|
# +-----------+----------------+--------------+----------+------+--------+---------+------------------+------------------+-----------------+----------+---------------+--------------------+-------------+----------+--------------------+
# only showing top 20 rows

# %%
# Criar view do df_1 para manipular na criação do df_2
df_1.createOrReplaceTempView("df_1")

# %%
# Verificar se há dias com previsão de chuva
df_distinct = spark.sql("""SELECT
                      DISTINCT vai_chover
                    FROM df_1""")

# %%
# Todas as previsões são de dias sem chuva
df_distinct.show()
# Out:
# +----------+
# |vai_chover|
# +----------+
# |       nao|
# +----------+

# %%
df_2 = spark.sql("""
                  WITH nao_chove AS(
                    SELECT
                      cidade as nome_cidade,
                      count(vai_chover) AS qtd_dias_nao_vai_chover,
                      count(cidade) as total_dias_mapeados
                    FROM df_1
                    WHERE vai_chover = 'nao'
                    GROUP BY cidade)
                    SELECT
                          B.nome_cidade,
                          CASE WHEN A.vai_chover = 'sim' THEN 1 ELSE null END AS qtd_dias_vai_chover,
                          B.qtd_dias_nao_vai_chover,
                          B.total_dias_mapeados
                    FROM df_1 as A
                    RIGHT JOIN nao_chove as B
                    ON A.cidade = B.nome_cidade
                    GROUP BY B.nome_cidade, B.qtd_dias_nao_vai_chover, B.total_dias_mapeados, A.vai_chover
                    """)

# %%
# Criar DF da Tabela 2
df_2 = spark.sql("""SELECT 
                      cidade, 
                      SUM(IF(vai_chover='sim',1,0)) as qtd_dias_vai_chover, 
                      SUM(IF(vai_chover='nao',1,0)) as qtd_dias_nao_vai_chover,
                      count(cidade) as TotalDiasMapeados
                    FROM df_1 
                    GROUP BY cidade""")

# %%
# Visualizar df_2
df_2.show()
# Out:
# +---------------+-------------------+-----------------------+-----------------+
# |         cidade|qtd_dias_vai_chover|qtd_dias_nao_vai_chover|TotalDiasMapeados|
# +---------------+-------------------+-----------------------+-----------------+
# |       Araruama|                  0|                      5|                5|
# |         Paraty|                  0|                      5|                5|
# |    Barra Mansa|                  0|                      5|                5|
# |     Porto Real|                  0|                      5|                5|
# |         Mendes|                  0|                      5|                5|
# |Cardoso Moreira|                  0|                      5|                5|
# |          Areal|                  0|                      5|                5|
# |      Itaperuna|                  0|                      5|                5|
# |      Paracambi|                  0|                      5|                5|
# |        Resende|                  0|                      5|                5|
# |       Itaocara|                  0|                      5|                5|
# |  Iguaba Grande|                  0|                      5|                5|
# |      Vassouras|                  0|                      5|                5|
# |   Silva Jardim|                  0|                      5|                5|
# |  Nova Friburgo|                  0|                      5|                5|
# |      Varre-Sai|                  0|                      5|                5|
# |  Volta Redonda|                  0|                      5|                5|
# |       Itatiaia|                  0|                      5|                5|
# |         Italva|                  0|                      5|                5|
# | Miguel Pereira|                  0|                      5|                5|
# +---------------+-------------------+-----------------------+-----------------+
# only showing top 20 rows

# %%
# Exportar CSVs
df_1.write.format("csv").save("/content/drive/final/tabela_1.csv")

# %%
df_2.write.format("csv").save("/content/drive/final/tabela_2.csv")
